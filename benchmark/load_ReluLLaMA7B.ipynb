# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="SparseLLM/ReluLLaMA-7B")

# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoConfig

tokenizer = AutoTokenizer.from_pretrained(
    "SparseLLM/ReluLLaMA-7B", use_fast=False
)
# output hidden state
config = AutoConfig.from_pretrained("SparseLLM/ReluLLaMA-7B", output_hidden_states=True)
model = AutoModelForCausalLM.from_pretrained("SparseLLM/ReluLLaMA-7B", config=config)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from calflops import calculate_flops
flops, macs, params = calculate_flops(
    model=model,
    input_shape=(1,11),
    output_as_string=True,
    output_precision=4,
    transformer_tokenizer=tokenizer
)
print("Alexnet FLOPs:%s   MACs:%s   Params:%s \n" % (flops, macs, params))
# Out:
# /home/kwu/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2653: FutureWarning: The `truncation_strategy` argument is deprecated and will be removed in a future version, use `truncation=True` to truncate examples to a max length. You can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to truncate to the maximal input size of the model (e.g. 512 for Bert).  If you have pairs of inputs, you can give a specific truncation strategy selected among `truncation='only_first'` (will only truncate the first sentence in the pairs) `truncation='only_second'` (will only truncate the second sentence in the pairs) or `truncation='longest_first'` (will iteratively remove tokens from the longest sentence in the pairs).
#   warnings.warn(
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ------------------------------------- Calculate Flops Results -------------------------------------
# Notations:
# number of parameters (Params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (FLOPs), floating-point operations per second (FLOPS),
# fwd FLOPs (model forward propagation FLOPs), bwd FLOPs (model backward propagation FLOPs),
# default model backpropagation takes 2.00 times as much computation as forward propagation.
#
# Total Training Params:                                                  6.74 B
# fwd MACs:                                                               72.6779 GMACs
# fwd FLOPs:                                                              145.36 GFLOPS
# fwd+bwd MACs:                                                           218.034 GMACs
# fwd+bwd FLOPs:                                                          436.079 GFLOPS
#
# -------------------------------- Detailed Calculated FLOPs Results --------------------------------
# Each module caculated is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, FLOPS, percentage of total FLOPs
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss).
#  They are not counted as submodules in calflops and not to be printed out. However they make up the difference between a parent's MACs and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
#
# LlamaForCausalLM(
#   6.74 B = 100% Params, 72.68 GMACs = 100% MACs, 145.36 GFLOPS = 49.9987% FLOPs
#   (model): LlamaModel(
#     6.61 B = 98.0549% Params, 71.24 GMACs = 98.0162% MACs, 142.48 GFLOPS = 49.0068% FLOPs
#     (embed_tokens): Embedding(131.07 M = 1.9451% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, 32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         202.38 M = 3.0034% Params, 2.23 GMACs = 3.063% MACs, 4.45 GFLOPS = 1.5315% FLOPs
#         (self_attn): LlamaSdpaAttention(
#           67.11 M = 0.9959% Params, 738.2 MMACs = 1.0157% MACs, 1.48 GFLOPS = 0.5078% FLOPs
#           (q_proj): Linear(16.78 M = 0.249% Params, 184.55 MMACs = 0.2539% MACs, 369.1 MFLOPS = 0.127% FLOPs, in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(16.78 M = 0.249% Params, 184.55 MMACs = 0.2539% MACs, 369.1 MFLOPS = 0.127% FLOPs, in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(16.78 M = 0.249% Params, 184.55 MMACs = 0.2539% MACs, 369.1 MFLOPS = 0.127% FLOPs, in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear(16.78 M = 0.249% Params, 184.55 MMACs = 0.2539% MACs, 369.1 MFLOPS = 0.127% FLOPs, in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         )
#         (mlp): LlamaMLP(
#           135.27 M = 2.0074% Params, 1.49 GMACs = 2.0473% MACs, 2.98 GFLOPS = 1.0236% FLOPs
#           (gate_proj): Linear(45.09 M = 0.6691% Params, 495.98 MMACs = 0.6824% MACs, 991.95 MFLOPS = 0.3412% FLOPs, in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear(45.09 M = 0.6691% Params, 495.98 MMACs = 0.6824% MACs, 991.95 MFLOPS = 0.3412% FLOPs, in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear(45.09 M = 0.6691% Params, 495.98 MMACs = 0.6824% MACs, 991.95 MFLOPS = 0.3412% FLOPs, in_features=11008, out_features=4096, bias=False)
#           (act_fn): ReLU(0 = 0% Params, 0 MACs = 0% MACs, 121.09 KFLOPS = 0% FLOPs)
#         )
#         (input_layernorm): LlamaRMSNorm(4.1 K = 0.0001% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#         (post_attention_layernorm): LlamaRMSNorm(4.1 K = 0.0001% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#       )
#     )
#     (norm): LlamaRMSNorm(4.1 K = 0.0001% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs)
#   )
#   (lm_head): Linear(131.07 M = 1.9451% Params, 1.44 GMACs = 1.9838% MACs, 2.88 GFLOPS = 0.9919% FLOPs, in_features=4096, out_features=32000, bias=False)
# )
# ---------------------------------------------------------------------------------------------------
# Alexnet FLOPs:145.36 GFLOPS   MACs:72.6779 GMACs   Params:6.7384 B

# %%
type(model)
# Out:
# transformers.models.llama.modeling_llama.LlamaForCausalLM

# %%
[module for module in model.named_modules()]
# Out:
# [('',
#   LlamaForCausalLM(
#     (model): LlamaModel(
#       (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#       (layers): ModuleList(
#         (0-31): 32 x LlamaDecoderLayer(
#           (self_attn): LlamaSdpaAttention(
#             (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (rotary_emb): LlamaRotaryEmbedding()
#           )
#           (mlp): LlamaMLP(
#             (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#             (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#             (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#             (act_fn): ReLU()
#           )
#           (input_layernorm): LlamaRMSNorm()
#           (post_attention_layernorm): LlamaRMSNorm()
#         )
#       )
#       (norm): LlamaRMSNorm()
#     )
#     (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#   )),
#  ('model',
#   LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#           (act_fn): ReLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )),
#  ('model.embed_tokens', Embedding(32000, 4096, padding_idx=0)),
#  ('model.layers',
#   ModuleList(
#     (0-31): 32 x LlamaDecoderLayer(
#       (self_attn): LlamaSdpaAttention(
#         (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (mlp): LlamaMLP(
#         (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#         (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#         (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#         (act_fn): ReLU()
#       )
#       (input_layernorm): LlamaRMSNorm()
#       (post_attention_layernorm): LlamaRMSNorm()
#     )
#   )),
#  ('model.layers.0',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.0.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.0.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.0.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.0.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.0.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.0.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.0.mlp.act_fn', ReLU()),
#  ('model.layers.0.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.0.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.1',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.1.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.1.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.1.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.1.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.1.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.1.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.1.mlp.act_fn', ReLU()),
#  ('model.layers.1.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.1.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.2',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.2.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.2.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.2.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.2.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.2.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.2.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.2.mlp.act_fn', ReLU()),
#  ('model.layers.2.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.2.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.3',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.3.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.3.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.3.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.3.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.3.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.3.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.3.mlp.act_fn', ReLU()),
#  ('model.layers.3.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.3.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.4',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.4.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.4.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.4.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.4.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.4.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.4.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.4.mlp.act_fn', ReLU()),
#  ('model.layers.4.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.4.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.5',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.5.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.5.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.5.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.5.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.5.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.5.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.5.mlp.act_fn', ReLU()),
#  ('model.layers.5.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.5.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.6',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.6.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.6.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.6.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.6.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.6.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.6.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.6.mlp.act_fn', ReLU()),
#  ('model.layers.6.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.6.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.7',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.7.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.7.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.7.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.7.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.7.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.7.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.7.mlp.act_fn', ReLU()),
#  ('model.layers.7.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.7.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.8',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.8.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.8.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.8.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.8.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.8.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.8.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.8.mlp.act_fn', ReLU()),
#  ('model.layers.8.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.8.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.9',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.9.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.9.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.9.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.9.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.9.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.9.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.9.mlp.act_fn', ReLU()),
#  ('model.layers.9.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.9.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.10',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.10.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.10.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.10.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.10.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.10.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.10.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.10.mlp.act_fn', ReLU()),
#  ('model.layers.10.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.10.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.11',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.11.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.11.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.11.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.11.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.11.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.11.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.11.mlp.act_fn', ReLU()),
#  ('model.layers.11.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.11.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.12',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.12.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.12.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.12.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.12.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.12.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.12.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.12.mlp.act_fn', ReLU()),
#  ('model.layers.12.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.12.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.13',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.13.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.13.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.13.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.13.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.13.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.13.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.13.mlp.act_fn', ReLU()),
#  ('model.layers.13.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.13.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.14',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.14.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.14.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.14.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.14.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.14.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.14.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.14.mlp.act_fn', ReLU()),
#  ('model.layers.14.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.14.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.15',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.15.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.15.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.15.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.15.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.15.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.15.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.15.mlp.act_fn', ReLU()),
#  ('model.layers.15.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.15.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.16',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.16.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.16.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.16.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.16.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.16.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.16.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.16.mlp.act_fn', ReLU()),
#  ('model.layers.16.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.16.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.17',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.17.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.17.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.17.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.17.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.17.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.17.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.17.mlp.act_fn', ReLU()),
#  ('model.layers.17.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.17.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.18',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.18.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.18.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.18.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.18.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.18.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.18.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.18.mlp.act_fn', ReLU()),
#  ('model.layers.18.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.18.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.19',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
# ...
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.25.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.25.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.25.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.25.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.25.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.25.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.25.mlp.act_fn', ReLU()),
#  ('model.layers.25.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.25.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.26',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.26.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.26.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.26.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.26.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.26.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.26.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.26.mlp.act_fn', ReLU()),
#  ('model.layers.26.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.26.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.27',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.27.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.27.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.27.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.27.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.27.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.27.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.27.mlp.act_fn', ReLU()),
#  ('model.layers.27.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.27.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.28',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.28.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.28.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.28.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.28.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.28.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.28.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.28.mlp.act_fn', ReLU()),
#  ('model.layers.28.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.28.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.29',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.29.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.29.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.29.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.29.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.29.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.29.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.29.mlp.act_fn', ReLU()),
#  ('model.layers.29.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.29.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.30',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.30.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.30.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.30.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.30.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.30.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.30.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.30.mlp.act_fn', ReLU()),
#  ('model.layers.30.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.30.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.31',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.31.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.31.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.31.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.31.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.31.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.31.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.31.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.31.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.31.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.31.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.31.mlp.act_fn', ReLU()),
#  ('model.layers.31.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.31.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.norm', LlamaRMSNorm()),
#  ('lm_head', Linear(in_features=4096, out_features=32000, bias=False))]

# %%
model.get_submodule("model.layers.31.mlp.act_fn")
# Out:
# ReLU()

# %%
from torchknickknacks import modelutils
layer = model.get_submodule("model.layers.18.mlp.act_fn")
layer2 = model.get_submodule("model.layers.31.mlp.down_proj")
recorder = modelutils.Recorder(layer, record_output=True, backward=False)
recorder2 = modelutils.Recorder(layer2, record_output=True, backward=False)

# %%
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors="pt")
output = model(**encoded_input)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 text = "Replace me by any text you'd like."
#       2 encoded_input = tokenizer(text, return_tensors="pt")
# ----> 3 output = model(**encoded_input)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1568, in Module._call_impl(self, *args, **kwargs)
#    1565     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1566     args = bw_hook.setup_input_hook(args)
# -> 1568 result = forward_call(*args, **kwargs)
#    1569 if _global_forward_hooks or self._forward_hooks:
#    1570     for hook_id, hook in (
#    1571         *_global_forward_hooks.items(),
#    1572         *self._forward_hooks.items(),
#    1573     ):
#    1574         # mark that always called hook is run
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1181, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1178 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1180 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1181 outputs = self.model(
#    1182     input_ids=input_ids,
#    1183     attention_mask=attention_mask,
#    1184     position_ids=position_ids,
#    1185     past_key_values=past_key_values,
#    1186     inputs_embeds=inputs_embeds,
#    1187     use_cache=use_cache,
#    1188     output_attentions=output_attentions,
#    1189     output_hidden_states=output_hidden_states,
#    1190     return_dict=return_dict,
#    1191 )
#    1193 hidden_states = outputs[0]
#    1194 if self.config.pretraining_tp > 1:
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1568, in Module._call_impl(self, *args, **kwargs)
#    1565     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1566     args = bw_hook.setup_input_hook(args)
# -> 1568 result = forward_call(*args, **kwargs)
#    1569 if _global_forward_hooks or self._forward_hooks:
#    1570     for hook_id, hook in (
#    1571         *_global_forward_hooks.items(),
#    1572         *self._forward_hooks.items(),
#    1573     ):
#    1574         # mark that always called hook is run
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1068, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1058     layer_outputs = self._gradient_checkpointing_func(
#    1059         decoder_layer.__call__,
#    1060         hidden_states,
#    (...)
#    1065         use_cache,
#    1066     )
#    1067 else:
# -> 1068     layer_outputs = decoder_layer(
#    1069         hidden_states,
#    1070         attention_mask=attention_mask,
#    1071         position_ids=position_ids,
#    1072         past_key_value=past_key_values,
#    1073         output_attentions=output_attentions,
#    1074         use_cache=use_cache,
#    1075     )
#    1077 hidden_states = layer_outputs[0]
#    1079 if use_cache:
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1568, in Module._call_impl(self, *args, **kwargs)
#    1565     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1566     args = bw_hook.setup_input_hook(args)
# -> 1568 result = forward_call(*args, **kwargs)
#    1569 if _global_forward_hooks or self._forward_hooks:
#    1570     for hook_id, hook in (
#    1571         *_global_forward_hooks.items(),
#    1572         *self._forward_hooks.items(),
#    1573     ):
#    1574         # mark that always called hook is run
#
# TypeError: ReLU.forward() got an unexpected keyword argument 'attention_mask'

# %%
print(recorder.recording)
print(recorder2.recording)
sum(sum(sum(recorder.recording == 0)))
# Out:
# tensor([[[0.0931, 0.0139, 0.0314,  ..., 0.0000, 0.0000, 0.0000],
#          [0.1245, 0.0000, 0.0000,  ..., 0.0265, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.2297, 0.0000,  ..., 0.0000, 0.0000, 0.5524],
#          [0.0000, 0.0022, 0.0000,  ..., 0.0000, 0.0000, 0.2228],
#          [0.1003, 0.0000, 0.0274,  ..., 0.0000, 0.0000, 0.0000]]],
#        grad_fn=<ReluBackward0>)
# tensor([[[-1.1766,  2.3352,  6.6595,  ...,  1.9904, -1.7416,  3.1122],
#          [-0.8362,  1.2037, -0.8024,  ..., -1.0820, -0.5340, -0.5148],
#          [ 1.0643, -0.9274, -1.4926,  ..., -0.8088, -1.6298, -1.8066],
#          ...,
#          [ 4.2380, -4.3821, -1.6420,  ..., -3.2197, -4.1690, -4.2523],
#          [ 3.2101, -2.4574,  0.7382,  ..., -2.9415,  0.8972, -2.0524],
#          [ 0.8878,  2.2958,  4.5667,  ...,  1.1654, -2.0586,  1.2388]]],
#        grad_fn=<UnsafeViewBackward0>)
# tensor(74572)

# %%
recorder.recording.shape
# Out:
# torch.Size([1, 11, 11008])

# %%
output.hidden_states[1]
# Out:
# tensor([[[ 0.0008, -0.0216,  0.0394,  ..., -0.0171, -0.0351,  0.0442],
#          [ 0.0371, -0.0065, -0.0127,  ...,  0.0360, -0.0056,  0.0015],
#          [ 0.0006, -0.0350,  0.0098,  ..., -0.0288,  0.0186, -0.0051],
#          ...,
#          [ 0.0021, -0.0060, -0.0308,  ...,  0.0009,  0.0104,  0.0362],
#          [ 0.0015,  0.0100,  0.0065,  ..., -0.0196,  0.0180, -0.0051],
#          [ 0.0113, -0.0060, -0.0134,  ..., -0.0091,  0.0101, -0.0051]]],
#        grad_fn=<AddBackward0>)

# %%
output.attentions
# output.pooler_output is not available for 'CausalLMOutputWithPast' object

# %%
wrapped_model = model.base_model
wrapped_model.__dict__
# Out:
# {'training': False,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_hooks_always_called': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('embed_tokens',
#                Embedding(32000, 4096, padding_idx=0)),
#               ('layers',
#                ModuleList(
#                  (0-31): 32 x LlamaDecoderLayer(
#                    (self_attn): LlamaSdpaAttention(
#                      (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#                      (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#                      (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#                      (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#                      (rotary_emb): LlamaRotaryEmbedding()
#                    )
#                    (mlp): LlamaMLP(
#                      (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#                      (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#                      (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#                      (act_fn): ReLU()
#                    )
#                    (input_layernorm): LlamaRMSNorm()
#                    (post_attention_layernorm): LlamaRMSNorm()
#                  )
#                )),
#               ('norm', LlamaRMSNorm())]),
#  'config': LlamaConfig {
#    "_name_or_path": "SparseLLM/ReluLLaMA-7B",
#    "architectures": [
#      "LlamaForCausalLM"
#    ],
#    "attention_bias": false,
#    "attention_dropout": 0.0,
#    "bos_token_id": 1,
#    "eos_token_id": 2,
#    "hidden_act": "relu",
#    "hidden_size": 4096,
#    "initializer_range": 0.02,
#    "intermediate_size": 11008,
#    "max_length": 4096,
#    "max_position_embeddings": 2048,
#    "model_type": "llama",
#    "num_attention_heads": 32,
#    "num_hidden_layers": 32,
#    "num_key_value_heads": 32,
#    "output_hidden_states": true,
#    "pad_token_id": 0,
#    "pretraining_tp": 1,
#    "rms_norm_eps": 1e-05,
#    "rope_scaling": null,
#    "rope_theta": 10000.0,
#    "tie_word_embeddings": false,
#    "torch_dtype": "float32",
#    "transformers_version": "4.36.2",
#    "use_cache": true,
#    "vocab_size": 32000
#  },
#  'name_or_path': 'SparseLLM/ReluLLaMA-7B',
#  'warnings_issued': {},
#  'generation_config': None,
#  '_keep_in_fp32_modules': None,
#  'padding_idx': 0,
#  'vocab_size': 32000,
#  '_use_sdpa': True,
#  '_use_flash_attention_2': False,
#  'gradient_checkpointing': False,
#  '_is_hf_initialized': True}

# %%
for idx, layer in enumerate(wrapped_model.layers):
    if idx == 0:
        print(layer.__dict__)
# Out:
# {'training': False, '_parameters': OrderedDict(), '_buffers': OrderedDict(), '_non_persistent_buffers_set': set(), '_backward_pre_hooks': OrderedDict(), '_backward_hooks': OrderedDict(), '_is_full_backward_hook': None, '_forward_hooks': OrderedDict(), '_forward_hooks_with_kwargs': OrderedDict(), '_forward_hooks_always_called': OrderedDict(), '_forward_pre_hooks': OrderedDict(), '_forward_pre_hooks_with_kwargs': OrderedDict(), '_state_dict_hooks': OrderedDict(), '_state_dict_pre_hooks': OrderedDict(), '_load_state_dict_pre_hooks': OrderedDict(), '_load_state_dict_post_hooks': OrderedDict(), '_modules': OrderedDict([('self_attn', LlamaSdpaAttention(
#   (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#   (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#   (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#   (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#   (rotary_emb): LlamaRotaryEmbedding()
# )), ('mlp', LlamaMLP(
#   (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#   (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#   (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#   (act_fn): ReLU()
# )), ('input_layernorm', LlamaRMSNorm()), ('post_attention_layernorm', LlamaRMSNorm())]), 'hidden_size': 4096, '_is_hf_initialized': True}

# %%
from peft.utils.other import _get_submodules
parent, target, target_name = _get_submodules(model, "model.layers.31")
from torch.nn import ReLU
setattr(parent, target_name, ReLU())

# %%
[module for module in model.named_modules()]
# Out:
# [('',
#   LlamaForCausalLM(
#     (model): LlamaModel(
#       (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#       (layers): ModuleList(
#         (0-30): 31 x LlamaDecoderLayer(
#           (self_attn): LlamaSdpaAttention(
#             (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (rotary_emb): LlamaRotaryEmbedding()
#           )
#           (mlp): LlamaMLP(
#             (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#             (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#             (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#             (act_fn): ReLU()
#           )
#           (input_layernorm): LlamaRMSNorm()
#           (post_attention_layernorm): LlamaRMSNorm()
#         )
#         (31): ReLU()
#       )
#       (norm): LlamaRMSNorm()
#     )
#     (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#   )),
#  ('model',
#   LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-30): 31 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#           (act_fn): ReLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#       (31): ReLU()
#     )
#     (norm): LlamaRMSNorm()
#   )),
#  ('model.embed_tokens', Embedding(32000, 4096, padding_idx=0)),
#  ('model.layers',
#   ModuleList(
#     (0-30): 31 x LlamaDecoderLayer(
#       (self_attn): LlamaSdpaAttention(
#         (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (mlp): LlamaMLP(
#         (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#         (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#         (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#         (act_fn): ReLU()
#       )
#       (input_layernorm): LlamaRMSNorm()
#       (post_attention_layernorm): LlamaRMSNorm()
#     )
#     (31): ReLU()
#   )),
#  ('model.layers.0',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.0.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.0.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.0.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.0.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.0.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.0.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.0.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.0.mlp.act_fn', ReLU()),
#  ('model.layers.0.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.0.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.1',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.1.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.1.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.1.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.1.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.1.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.1.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.1.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.1.mlp.act_fn', ReLU()),
#  ('model.layers.1.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.1.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.2',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.2.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.2.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.2.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.2.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.2.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.2.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.2.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.2.mlp.act_fn', ReLU()),
#  ('model.layers.2.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.2.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.3',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.3.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.3.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.3.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.3.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.3.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.3.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.3.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.3.mlp.act_fn', ReLU()),
#  ('model.layers.3.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.3.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.4',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.4.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.4.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.4.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.4.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.4.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.4.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.4.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.4.mlp.act_fn', ReLU()),
#  ('model.layers.4.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.4.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.5',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.5.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.5.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.5.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.5.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.5.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.5.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.5.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.5.mlp.act_fn', ReLU()),
#  ('model.layers.5.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.5.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.6',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.6.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.6.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.6.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.6.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.6.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.6.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.6.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.6.mlp.act_fn', ReLU()),
#  ('model.layers.6.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.6.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.7',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.7.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.7.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.7.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.7.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.7.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.7.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.7.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.7.mlp.act_fn', ReLU()),
#  ('model.layers.7.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.7.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.8',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.8.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.8.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.8.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.8.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.8.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.8.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.8.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.8.mlp.act_fn', ReLU()),
#  ('model.layers.8.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.8.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.9',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.9.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.9.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.9.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.9.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.9.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.9.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.9.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.9.mlp.act_fn', ReLU()),
#  ('model.layers.9.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.9.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.10',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.10.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.10.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.10.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.10.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.10.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.10.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.10.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.10.mlp.act_fn', ReLU()),
#  ('model.layers.10.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.10.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.11',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.11.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.11.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.11.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.11.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.11.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.11.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.11.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.11.mlp.act_fn', ReLU()),
#  ('model.layers.11.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.11.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.12',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.12.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.12.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.12.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.12.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.12.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.12.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.12.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.12.mlp.act_fn', ReLU()),
#  ('model.layers.12.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.12.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.13',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.13.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.13.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.13.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.13.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.13.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.13.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.13.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.13.mlp.act_fn', ReLU()),
#  ('model.layers.13.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.13.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.14',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.14.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.14.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.14.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.14.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.14.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.14.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.14.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.14.mlp.act_fn', ReLU()),
#  ('model.layers.14.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.14.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.15',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.15.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.15.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.15.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.15.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.15.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.15.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.15.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.15.mlp.act_fn', ReLU()),
#  ('model.layers.15.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.15.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.16',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.16.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.16.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.16.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.16.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.16.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.16.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.16.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.16.mlp.act_fn', ReLU()),
#  ('model.layers.16.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.16.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.17',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.17.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.17.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.17.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.17.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.17.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.17.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.17.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.17.mlp.act_fn', ReLU()),
#  ('model.layers.17.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.17.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.18',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.18.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.18.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.18.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.18.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.18.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.18.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.18.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.18.mlp.act_fn', ReLU()),
#  ('model.layers.18.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.18.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.19',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
# ...
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.24.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.24.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.24.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.24.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.24.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.24.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.24.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.24.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.24.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.24.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.24.mlp.act_fn', ReLU()),
#  ('model.layers.24.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.24.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.25',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.25.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.25.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.25.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.25.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.25.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.25.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.25.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.25.mlp.act_fn', ReLU()),
#  ('model.layers.25.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.25.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.26',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.26.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.26.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.26.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.26.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.26.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.26.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.26.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.26.mlp.act_fn', ReLU()),
#  ('model.layers.26.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.26.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.27',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.27.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.27.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.27.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.27.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.27.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.27.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.27.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.27.mlp.act_fn', ReLU()),
#  ('model.layers.27.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.27.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.28',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.28.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.28.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.28.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.28.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.28.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.28.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.28.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.28.mlp.act_fn', ReLU()),
#  ('model.layers.28.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.28.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.29',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.29.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.29.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.29.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.29.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.29.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.29.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.29.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.29.mlp.act_fn', ReLU()),
#  ('model.layers.29.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.29.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.30',
#   LlamaDecoderLayer(
#     (self_attn): LlamaSdpaAttention(
#       (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#       (rotary_emb): LlamaRotaryEmbedding()
#     )
#     (mlp): LlamaMLP(
#       (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#       (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#       (act_fn): ReLU()
#     )
#     (input_layernorm): LlamaRMSNorm()
#     (post_attention_layernorm): LlamaRMSNorm()
#   )),
#  ('model.layers.30.self_attn',
#   LlamaSdpaAttention(
#     (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )),
#  ('model.layers.30.self_attn.q_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.k_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.v_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.o_proj',
#   Linear(in_features=4096, out_features=4096, bias=False)),
#  ('model.layers.30.self_attn.rotary_emb', LlamaRotaryEmbedding()),
#  ('model.layers.30.mlp',
#   LlamaMLP(
#     (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#     (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#     (act_fn): ReLU()
#   )),
#  ('model.layers.30.mlp.gate_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.30.mlp.up_proj',
#   Linear(in_features=4096, out_features=11008, bias=False)),
#  ('model.layers.30.mlp.down_proj',
#   Linear(in_features=11008, out_features=4096, bias=False)),
#  ('model.layers.30.mlp.act_fn', ReLU()),
#  ('model.layers.30.input_layernorm', LlamaRMSNorm()),
#  ('model.layers.30.post_attention_layernorm', LlamaRMSNorm()),
#  ('model.layers.31', ReLU()),
#  ('model.norm', LlamaRMSNorm()),
#  ('lm_head', Linear(in_features=4096, out_features=32000, bias=False))]

# %%
_get_submodules(model, "model.layers.31.mlp")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 _get_submodules(model, "model.layers.31.mlp")
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/peft/utils/other.py:259, in _get_submodules(model, key)
#     257 parent = model.get_submodule(".".join(key.split(".")[:-1]))
#     258 target_name = key.split(".")[-1]
# --> 259 target = model.get_submodule(key)
#     260 return parent, target, target_name
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:686, in Module.get_submodule(self, target)
#     683 for item in atoms:
#     685     if not hasattr(mod, item):
# --> 686         raise AttributeError(mod._get_name() + " has no "
#     687                              "attribute `" + item + "`")
#     689     mod = getattr(mod, item)
#     691     if not isinstance(mod, torch.nn.Module):
#
# AttributeError: ReLU has no attribute `mlp`

# %%
output = model(**encoded_input)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 output = model(**encoded_input)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1181, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1178 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1180 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1181 outputs = self.model(
#    1182     input_ids=input_ids,
#    1183     attention_mask=attention_mask,
#    1184     position_ids=position_ids,
#    1185     past_key_values=past_key_values,
#    1186     inputs_embeds=inputs_embeds,
#    1187     use_cache=use_cache,
#    1188     output_attentions=output_attentions,
#    1189     output_hidden_states=output_hidden_states,
#    1190     return_dict=return_dict,
#    1191 )
#    1193 hidden_states = outputs[0]
#    1194 if self.config.pretraining_tp > 1:
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/transformers/models/llama/modeling_llama.py:1068, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1058     layer_outputs = self._gradient_checkpointing_func(
#    1059         decoder_layer.__call__,
#    1060         hidden_states,
#    (...)
#    1065         use_cache,
#    1066     )
#    1067 else:
# -> 1068     layer_outputs = decoder_layer(
#    1069         hidden_states,
#    1070         attention_mask=attention_mask,
#    1071         position_ids=position_ids,
#    1072         past_key_value=past_key_values,
#    1073         output_attentions=output_attentions,
#    1074         use_cache=use_cache,
#    1075     )
#    1077 hidden_states = layer_outputs[0]
#    1079 if use_cache:
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/dev_cupy_graph/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# TypeError: ReLU.forward() got an unexpected keyword argument 'attention_mask'
